# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import sklearn

# %%
dataset = pd.read_csv('Dataset_Loan.csv')
dataset.head()

# %%
dataset.shape

# %%
dataset.isnull().sum()

# %%
(dataset.isnull().sum()/dataset.shape[0])*100

# %%
total_val = dataset.shape[0]*dataset.shape[1]

# %%
total_nan = (dataset.isnull().sum().sum() / total_val ) *100

# %%
total_nan

# %%
sns.heatmap(dataset.isnull())
plt.show()

# %% [markdown]
# How to fill missing data

# %%
dataset

# %%
dataset = dataset.bfill()
dataset

# %%
dataset.info()

# %%
dataset["Gender"].fillna(dataset["Gender"].mode()[0] , inplace= True)

# %%
dataset.select_dtypes(include=str).isnull().sum()
dataset.isnull().sum()

# %%
for i in dataset.select_dtypes(include="object").columns:
    dataset[i] = dataset[i].fillna(dataset[i].mode()[0])

dataset.isnull().sum()

# %%
dataset.isnull().sum()

# %%
dataset.select_dtypes(include='Float64').columns

# %%
from sklearn.impute import SimpleImputer

si = SimpleImputer(strategy="mean")
arr = si.fit_transform(dataset[['CoapplicantIncome', 'LoanAmount', 'Loan_Amount_Term',
       'Credit_History']])

# %%
new_dataset = pd.DataFrame(arr , columns= dataset.select_dtypes(include='Float64').columns )
new_dataset.isnull().sum()

# %% [markdown]
# ### One Hot Encoding

# %%
dataset.isnull().sum()

# %%
dataset['Married'] = dataset['Married'].fillna(dataset['Married'].mode()[0] , inplace = True)
dataset.isnull().sum()

# %%
from sklearn.preprocessing import OneHotEncoder

ohe = OneHotEncoder()
arr = ohe.fit_transform(dataset [["Married" , "Gender"]]).toarray()

# %%
pd.DataFrame(arr , columns= ['Gender_Female' , 'Gender_Male' , 'Married_Yes' , 'Married_No'])
